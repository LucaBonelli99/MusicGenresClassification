# %%
import numpy as np
import pandas as pd
import IPython.display as ipd
from sklearn.preprocessing import StandardScaler

mfcc = pd.read_csv('mfcc_not_scaled.csv', index_col = 0, header = [0,1,2])

#mfcc = mfcc.drop(mfcc.columns[[12,13,14,15,16,17,18,19,32,33,34,35,36,37,38,39,52,53,54,55,56,57,58,59,72,73,74,75,76,77,78,79,92,93,94,95,96,97,98,99,112,113,114,115,116,117,118,119,132,133,134,135,136,137,138,139]], axis=1)


chroma = pd.read_csv('chroma_not_scaled.csv', index_col = 0, header = [0,1,2])
zcr = pd.read_csv('zcr_not_scaled.csv', index_col = 0, header = [0,1])
centroid_rolloff = pd.read_csv('centroid_rolloff_bandwidth_not_scaled.csv', index_col = 0, header = [0,1])
contrast = pd.read_csv('contrast_not_scaled.csv', index_col = 0, header = [0,1,2])

#pitch_changes = pd.read_csv('pitch_changes.csv', index_col = 0, header = [0])

unscaled_df = mfcc.join([chroma, zcr, centroid_rolloff, contrast])
unscaled_df = unscaled_df.dropna()

ipd.display(unscaled_df)


unscaled_df.to_csv('complete_unscaled_dataset.csv')
# Out:
#           (mfcc, mean, 1)  (mfcc, mean, 2)  (mfcc, mean, 3)  (mfcc, mean, 4)  \
# track_id
# 2              -67.384201        65.155075       -10.669196        12.176932
# 3              -97.992485        72.889534        -3.973132        30.070477
# 5             -106.587730        87.239357        12.156827        24.140398
# 10             -17.238174        94.442024       -48.614548        32.370766
# 134            -84.152870        84.352127        -2.286359        34.442200
# ...                   ...              ...              ...              ...
# 155304         -79.091148        86.971321        13.332952        42.796810
# 155305        -192.851105       133.374039        30.840197        33.762676
# 155306        -217.283554       162.253387        -1.447354        32.816235
# 155307        -167.747559        87.483261         6.906166        19.528233
# 155314         -82.922188       110.042313       -19.682865        35.809292
#
#           (mfcc, mean, 5)  (mfcc, mean, 6)  (mfcc, mean, 7)  (mfcc, mean, 8)  \
# track_id
# 2               -3.303557         9.916471        -1.985740         5.415339
# 3                5.172878        12.528610        -4.383329         7.048224
# 5               -0.970479        12.831119        -5.540452        17.374945
# 10              -4.550584         2.220590        -2.271865         2.682117
# 134              4.921756         8.355569         4.027512        19.810892
# ...                   ...              ...              ...              ...
# 155304           4.142479        13.474188         9.935136         5.118958
# 155305          13.907678        -3.243983         0.447482        -3.514450
# 155306          12.884858         3.195513         4.707439        -3.388822
# 155307           7.469274        13.833449         6.312596        10.696968
# 155314          -0.158643         1.059259        -2.193566        14.071067
#
#           (mfcc, mean, 9)  (mfcc, mean, 10)  ...  (contrast, skew, 3)  \
# track_id                                     ...
# 2               -6.161758          1.091336  ...             0.249772
# 3               -8.217740          7.234849  ...             0.341326
# 5               -6.245709         -0.075109  ...             0.050779
# 10              -5.288854          0.512593  ...             0.329046
# 134              0.851138         10.797225  ...             0.397883
# ...                   ...               ...  ...                  ...
# 155304          -5.375656          4.953872  ...             0.240071
# 155305         -15.443760          6.417903  ...             0.411566
# 155306          -0.604373          1.220779  ...             0.411181
# 155307          -4.173703          6.168261  ...             0.349458
# 155314          -7.260611          5.439314  ...             0.695544
#
#           (contrast, skew, 4)  (contrast, skew, 5)  (contrast, skew, 6)  \
# track_id
# 2                    0.258381             0.378909             0.744925
# 3                    0.129170            -0.095684             0.311029
# 5                    0.047427             0.273518             0.897610
# 10                   0.269207             0.332886             0.402207
# 134                  0.624900             0.448236             0.622428
# ...                       ...                  ...                  ...
# 155304              -0.221312            -0.074339             0.419140
# 155305               0.095613             0.305361             0.699289
# 155306               0.272987             0.483412             0.183274
# 155307               0.306182             0.595744             0.616606
# 155314               0.447338             0.481320             0.565310
#
#           (contrast, kurtosis, 1)  (contrast, kurtosis, 2)  \
# track_id
# 2                        3.803164                -0.018434
# 3                        1.241463                 1.104689
# 5                        1.242473                 1.775691
# 10                       3.636584                 0.742408
# 134                      6.003963                 0.684611
# ...                           ...                      ...
# 155304                   4.392640                 0.723130
# 155305                   2.769350                 0.068707
# 155306                   5.026873                 0.892219
# 155307                   1.921619                -0.011839
# 155314                   3.191101                 1.239003
#
#           (contrast, kurtosis, 3)  (contrast, kurtosis, 4)  \
# track_id
# 2                        0.073019                 0.147885
# 3                        0.136208                -0.548991
# 5                        0.069869                 0.671903
# 10                       0.366582                 0.777638
# 134                      0.284433                 0.538790
# ...                           ...                      ...
# 155304                   0.299717                 0.083636
# 155305                   1.141640                -0.064294
# 155306                   0.539851                 0.134641
# 155307                  -0.262105                -0.664807
# 155314                   0.876661                 0.258984
#
#           (contrast, kurtosis, 5)  (contrast, kurtosis, 6)
# track_id
# 2                        0.219722                 0.612398
# 3                       -0.074470                 0.075461
# 5                        0.269572                 2.383789
# 10                       1.636699                 0.900061
# 134                      0.211476                 0.279040
# ...                           ...                      ...
# 155304                  -0.160900                -0.292233
# 155305                  -0.147984                 0.391955
# 155306                   0.157030                 0.926083
# 155307                  -0.387809                -0.170939
# 155314                   0.556226                 0.568842
#
# [29951 rows x 230 columns]

# %%
import numpy as np
import pandas as pd
import IPython.display as ipd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X = pd.read_csv('complete_unscaled_dataset2.csv', index_col = 0, header = [0])
ipd.display(X)

tracks_genres = pd.read_csv('tracks_genres_mio.csv', index_col = 0, header = [0])
#Alcune tracce presenti in tracks_genres.csv potrebbero non funzionare, quindi tengo solo le tracce di cui sono riuscito ad estrarre le feature
y = tracks_genres.loc[X.index,  'genre']

#Divido training e test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)


#X = pd.DataFrame(data=scaled, index = unscaled_df.index, columns = unscaled_df.columns )
#X.index.name = 'track_id'

#Fit e scaling sul training set
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Oversampling dei dati di training
#SMOTE resampling
#from imblearn.over_sampling import SMOTE, ADASYN
#X_train_resampled, y_train_resampled = SMOTE().fit_resample(X_train_scaled, y_train)

#Oversampling dei dati di training
#SVM SMOTE resampling
from imblearn.over_sampling import SVMSMOTE
X_train_resampled, y_train_resampled = SVMSMOTE().fit_resample(X_train_scaled, y_train)

ipd.display(X_train_resampled)

#SMOTE ENN (smote + pulizia)
#from imblearn.combine import SMOTEENN
#smote_enn = SMOTEENN(random_state=42)
#X_train_resampled, y_train_resampled = smote_enn.fit_resample(X_train_scaled, y_train)
# Out:
#           ('mfcc', 'mean', '1')  ('mfcc', 'mean', '2')  ('mfcc', 'mean', '3')  \
# track_id
# 2                    -67.384201              65.155075             -10.669196
# 3                    -97.992485              72.889534              -3.973132
# 5                   -106.587730              87.239357              12.156827
# 10                   -17.238174              94.442024             -48.614548
# 134                  -84.152870              84.352127              -2.286359
# ...                         ...                    ...                    ...
# 155304               -79.091148              86.971321              13.332952
# 155305              -192.851105             133.374039              30.840197
# 155306              -217.283554             162.253387              -1.447354
# 155307              -167.747559              87.483261               6.906166
# 155314               -82.922188             110.042313             -19.682865
#
#           ('mfcc', 'mean', '4')  ('mfcc', 'mean', '5')  ('mfcc', 'mean', '6')  \
# track_id
# 2                     12.176932              -3.303557               9.916471
# 3                     30.070477               5.172878              12.528610
# 5                     24.140398              -0.970479              12.831119
# 10                    32.370766              -4.550584               2.220590
# 134                   34.442200               4.921756               8.355569
# ...                         ...                    ...                    ...
# 155304                42.796810               4.142479              13.474188
# 155305                33.762676              13.907678              -3.243983
# 155306                32.816235              12.884858               3.195513
# 155307                19.528233               7.469274              13.833449
# 155314                35.809292              -0.158643               1.059259
#
#           ('mfcc', 'mean', '7')  ('mfcc', 'mean', '8')  ('mfcc', 'mean', '9')  \
# track_id
# 2                     -1.985740               5.415339              -6.161758
# 3                     -4.383329               7.048224              -8.217740
# 5                     -5.540452              17.374945              -6.245709
# 10                    -2.271865               2.682117              -5.288854
# 134                    4.027512              19.810892               0.851138
# ...                         ...                    ...                    ...
# 155304                 9.935136               5.118958              -5.375656
# 155305                 0.447482              -3.514450             -15.443760
# 155306                 4.707439              -3.388822              -0.604373
# 155307                 6.312596              10.696968              -4.173703
# 155314                -2.193566              14.071067              -7.260611
#
#           ('mfcc', 'mean', '10')  ...  ('contrast', 'skew', '3')  \
# track_id                          ...
# 2                       1.091336  ...                   0.249772
# 3                       7.234849  ...                   0.341326
# 5                      -0.075109  ...                   0.050779
# 10                      0.512593  ...                   0.329046
# 134                    10.797225  ...                   0.397883
# ...                          ...  ...                        ...
# 155304                  4.953872  ...                   0.240071
# 155305                  6.417903  ...                   0.411566
# 155306                  1.220779  ...                   0.411181
# 155307                  6.168261  ...                   0.349458
# 155314                  5.439314  ...                   0.695544
#
#           ('contrast', 'skew', '4')  ('contrast', 'skew', '5')  \
# track_id
# 2                          0.258381                   0.378909
# 3                          0.129170                  -0.095684
# 5                          0.047427                   0.273518
# 10                         0.269207                   0.332886
# 134                        0.624900                   0.448236
# ...                             ...                        ...
# 155304                    -0.221312                  -0.074339
# 155305                     0.095613                   0.305361
# 155306                     0.272987                   0.483412
# 155307                     0.306182                   0.595744
# 155314                     0.447338                   0.481320
#
#           ('contrast', 'skew', '6')  ('contrast', 'kurtosis', '1')  \
# track_id
# 2                          0.744925                       3.803164
# 3                          0.311029                       1.241463
# 5                          0.897610                       1.242473
# 10                         0.402207                       3.636584
# 134                        0.622428                       6.003963
# ...                             ...                            ...
# 155304                     0.419140                       4.392640
# 155305                     0.699289                       2.769350
# 155306                     0.183274                       5.026873
# 155307                     0.616606                       1.921619
# 155314                     0.565310                       3.191101
#
#           ('contrast', 'kurtosis', '2')  ('contrast', 'kurtosis', '3')  \
# track_id
# 2                             -0.018434                       0.073019
# 3                              1.104689                       0.136208
# 5                              1.775691                       0.069869
# 10                             0.742408                       0.366582
# 134                            0.684611                       0.284433
# ...                                 ...                            ...
# 155304                         0.723130                       0.299717
# 155305                         0.068707                       1.141640
# 155306                         0.892219                       0.539851
# 155307                        -0.011839                      -0.262105
# 155314                         1.239003                       0.876661
#
#           ('contrast', 'kurtosis', '4')  ('contrast', 'kurtosis', '5')  \
# track_id
# 2                              0.147885                       0.219722
# 3                             -0.548991                      -0.074470
# 5                              0.671903                       0.269572
# 10                             0.777638                       1.636699
# 134                            0.538790                       0.211476
# ...                                 ...                            ...
# 155304                         0.083636                      -0.160900
# 155305                        -0.064294                      -0.147984
# 155306                         0.134641                       0.157030
# 155307                        -0.664807                      -0.387809
# 155314                         0.258984                       0.556226
#
#           ('contrast', 'kurtosis', '6')
# track_id
# 2                              0.612398
# 3                              0.075461
# 5                              2.383789
# 10                             0.900061
# 134                            0.279040
# ...                                 ...
# 155304                        -0.292233
# 155305                         0.391955
# 155306                         0.926083
# 155307                        -0.170939
# 155314                         0.568842
#
# [27789 rows x 230 columns]
# array([[ 3.58345645e-01, -3.92124829e-01, -6.25092037e-01, ...,
#         -4.02168898e-01, -5.25695759e-01, -6.19254103e-01],
#        [-6.49440063e-01,  5.68523914e-01, -3.78565372e-01, ...,
#          1.53522719e+00, -1.38325991e-01,  4.50547376e-01],
#        [-2.27872141e-02, -4.50541730e-01,  4.78276110e-02, ...,
#          2.92732604e-01, -3.59217325e-01,  5.69084955e-01],
#        ...,
#        [-8.41042151e-01,  1.75900106e+00, -2.62811521e+00, ...,
#          3.13818874e-01,  4.10322820e-01,  1.95579763e-02],
#        [ 5.82865895e-01, -3.28866833e-01,  6.76194664e-02, ...,
#         -5.86007109e-02, -4.50432827e-01, -4.06160240e-01],
#        [ 7.94255535e-01, -1.03226638e+00, -4.62043031e-01, ...,
#          1.47402645e+00,  1.00505212e+00,  1.94459013e-03]])

# %%
from sklearn import svm
import joblib

#clf = svm.SVC(kernel='rbf', decision_function_shape='ovo', gamma = 'auto')
#scores = cross_val_score(clf, X_train_resampled, y_train_resampled, cv=5)

clf = svm.SVC(kernel='rbf', decision_function_shape='ovo', gamma = 'auto')
# Fit data
clf = clf.fit(X_train_resampled, y_train_resampled)

joblib.dump(scaler, "Scaler.joblib")
joblib.dump(clf, "SVMClassifier.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-431127a52142> in <module>
#       3
#       4 clf = svm.SVC(kernel='rbf', decision_function_shape='ovo', gamma = 'auto')
# ----> 5 scores = cross_val_score(clf, X_train_resampled, y_train_resampled, cv=5)
#       6
#       7 #clf = svm.SVC(kernel='rbf', decision_function_shape='ovo', gamma = 'auto')
#
# NameError: name 'cross_val_score' is not defined

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

#Scaling sul test set
clf = joblib.load("SVMClassifier.joblib") 

scaler = joblib.load("Scaler.joblib") 
X_test_scaled = scaler.transform(X_test)


# Predict the test set
predictions = clf.predict(X_test_scaled)
# Generate confusion matrix
matrix = plot_confusion_matrix(clf, X_test_scaled, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Matrice di confusione')
plt.show(matrix)

print(classification_report(y_test, predictions))


print("Accuracy: ", accuracy_score(y_test, predictions))

(unique, counts) = np.unique(predictions, return_counts=True)
frequencies = np.asarray((unique, counts)).T

print("\nNumero di tracce assegnate ad ogni classe: \n", frequencies)
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.65      0.68      0.67      2104
#  Experimental       0.43      0.40      0.41       739
#          Folk       0.60      0.71      0.65       915
#       Hip-Hop       0.62      0.75      0.68      1136
#  Instrumental       0.47      0.46      0.46       718
# International       0.54      0.51      0.52       457
#           Pop       0.42      0.21      0.28       765
#          Rock       0.77      0.77      0.77      2337
#
#      accuracy                           0.63      9171
#     macro avg       0.56      0.56      0.55      9171
#  weighted avg       0.62      0.63      0.62      9171
#
# Accuracy:  0.6253407480100316
#
# Numero di tracce assegnate ad ogni classe:
#  [['Electronic' 2199]
#  ['Experimental' 686]
#  ['Folk' 1085]
#  ['Hip-Hop' 1363]
#  ['Instrumental' 699]
#  ['International' 429]
#  ['Pop' 379]
#  ['Rock' 2331]]
