# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
import IPython.display as ipd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = pd.read_csv('complete_unscaled_dataset2.csv', index_col = 0, header = [0])

tracks_genres = pd.read_csv('tracks_genres_mio2.csv', index_col = 0, header = [0])
#Alcune tracce presenti in tracks_genres.csv potrebbero non funzionare, quindi tengo solo le tracce di cui sono riuscito ad estrarre le feature
y = tracks_genres.loc[X.index,  'genre']

#Divido training e test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

#Fit e scaling sul training set
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Oversampling dei dati di training
#SMOTE resampling
#from imblearn.over_sampling import SMOTE, ADASYN
#X_resampled, y_resampled = SMOTE().fit_resample(X_scaled, y)

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select = 172, step=10, verbose=5)
rfe_selector.fit(X_train_scaled, y_train)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# Fitting estimator with 230 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 220 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 210 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 200 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 190 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting estimator with 180 features.
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 172 selected features
# c:\users\bonno\anaconda3\envs\projectenv\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
ipd.display(rfe_feature)
# Out:
# ["('mfcc', 'mean', '1')",
#  "('mfcc', 'mean', '2')",
#  "('mfcc', 'mean', '3')",
#  "('mfcc', 'mean', '4')",
#  "('mfcc', 'mean', '5')",
#  "('mfcc', 'mean', '6')",
#  "('mfcc', 'mean', '7')",
#  "('mfcc', 'mean', '8')",
#  "('mfcc', 'mean', '9')",
#  "('mfcc', 'mean', '11')",
#  "('mfcc', 'mean', '12')",
#  "('mfcc', 'std', '1')",
#  "('mfcc', 'std', '2')",
#  "('mfcc', 'std', '3')",
#  "('mfcc', 'std', '4')",
#  "('mfcc', 'std', '5')",
#  "('mfcc', 'std', '6')",
#  "('mfcc', 'std', '7')",
#  "('mfcc', 'std', '8')",
#  "('mfcc', 'std', '10')",
#  "('mfcc', 'std', '11')",
#  "('mfcc', 'std', '12')",
#  "('mfcc', 'max', '1')",
#  "('mfcc', 'max', '2')",
#  "('mfcc', 'max', '3')",
#  "('mfcc', 'max', '4')",
#  "('mfcc', 'max', '5')",
#  "('mfcc', 'max', '6')",
#  "('mfcc', 'max', '7')",
#  "('mfcc', 'max', '9')",
#  "('mfcc', 'max', '11')",
#  "('mfcc', 'min', '1')",
#  "('mfcc', 'min', '2')",
#  "('mfcc', 'min', '3')",
#  "('mfcc', 'min', '4')",
#  "('mfcc', 'min', '5')",
#  "('mfcc', 'min', '6')",
#  "('mfcc', 'min', '8')",
#  "('mfcc', 'min', '9')",
#  "('mfcc', 'min', '10')",
#  "('mfcc', 'min', '11')",
#  "('mfcc', 'median', '1')",
#  "('mfcc', 'median', '2')",
#  "('mfcc', 'median', '3')",
#  "('mfcc', 'median', '4')",
#  "('mfcc', 'median', '5')",
#  "('mfcc', 'median', '6')",
#  "('mfcc', 'median', '7')",
#  "('mfcc', 'median', '8')",
#  "('mfcc', 'median', '9')",
#  "('mfcc', 'median', '11')",
#  "('mfcc', 'median', '12')",
#  "('mfcc', 'skew', '1')",
#  "('mfcc', 'skew', '2')",
#  "('mfcc', 'skew', '3')",
#  "('mfcc', 'kurtosis', '1')",
#  "('mfcc', 'kurtosis', '2')",
#  "('mfcc', 'kurtosis', '6')",
#  "('chroma', 'mean', '1')",
#  "('chroma', 'mean', '2')",
#  "('chroma', 'mean', '3')",
#  "('chroma', 'mean', '4')",
#  "('chroma', 'mean', '5')",
#  "('chroma', 'mean', '6')",
#  "('chroma', 'mean', '7')",
#  "('chroma', 'mean', '8')",
#  "('chroma', 'mean', '9')",
#  "('chroma', 'mean', '10')",
#  "('chroma', 'mean', '11')",
#  "('chroma', 'mean', '12')",
#  "('chroma', 'std', '2')",
#  "('chroma', 'std', '4')",
#  "('chroma', 'std', '7')",
#  "('chroma', 'std', '11')",
#  "('chroma', 'std', '12')",
#  "('chroma', 'max', '3')",
#  "('chroma', 'max', '4')",
#  "('chroma', 'max', '10')",
#  "('chroma', 'max', '12')",
#  "('chroma', 'min', '2')",
#  "('chroma', 'min', '3')",
#  "('chroma', 'min', '4')",
#  "('chroma', 'min', '5')",
#  "('chroma', 'min', '10')",
#  "('chroma', 'min', '11')",
#  "('chroma', 'min', '12')",
#  "('chroma', 'median', '1')",
#  "('chroma', 'median', '2')",
#  "('chroma', 'median', '3')",
#  "('chroma', 'median', '4')",
#  "('chroma', 'median', '5')",
#  "('chroma', 'median', '6')",
#  "('chroma', 'median', '8')",
#  "('chroma', 'median', '9')",
#  "('chroma', 'median', '10')",
#  "('chroma', 'median', '11')",
#  "('chroma', 'skew', '1')",
#  "('chroma', 'skew', '2')",
#  "('chroma', 'skew', '3')",
#  "('chroma', 'skew', '4')",
#  "('chroma', 'skew', '5')",
#  "('chroma', 'skew', '6')",
#  "('chroma', 'skew', '7')",
#  "('chroma', 'skew', '8')",
#  "('chroma', 'skew', '9')",
#  "('chroma', 'skew', '11')",
#  "('chroma', 'skew', '12')",
#  "('chroma', 'kurtosis', '1')",
#  "('chroma', 'kurtosis', '2')",
#  "('chroma', 'kurtosis', '3')",
#  "('chroma', 'kurtosis', '4')",
#  "('chroma', 'kurtosis', '5')",
#  "('chroma', 'kurtosis', '6')",
#  "('chroma', 'kurtosis', '7')",
#  "('chroma', 'kurtosis', '8')",
#  "('chroma', 'kurtosis', '9')",
#  "('chroma', 'kurtosis', '10')",
#  "('chroma', 'kurtosis', '11')",
#  "('chroma', 'kurtosis', '12')",
#  "('zcr', 'mean')",
#  "('zcr', 'std')",
#  "('zcr', 'max')",
#  "('zcr', 'min')",
#  "('zcr', 'median')",
#  "('centroid', 'mean')",
#  "('centroid', 'std')",
#  "('centroid', 'max')",
#  "('centroid', 'min')",
#  "('centroid', 'median')",
#  "('rolloff', 'mean')",
#  "('rolloff', 'std')",
#  "('rolloff', 'max')",
#  "('rolloff', 'min')",
#  "('rolloff', 'median')",
#  "('bandwidth', 'mean')",
#  "('bandwidth', 'std')",
#  "('bandwidth', 'max')",
#  "('bandwidth', 'min')",
#  "('bandwidth', 'median')",
#  "('contrast', 'mean', '1')",
#  "('contrast', 'mean', '2')",
#  "('contrast', 'mean', '3')",
#  "('contrast', 'mean', '4')",
#  "('contrast', 'mean', '5')",
#  "('contrast', 'mean', '6')",
#  "('contrast', 'std', '2')",
#  "('contrast', 'std', '3')",
#  "('contrast', 'std', '4')",
#  "('contrast', 'std', '5')",
#  "('contrast', 'std', '6')",
#  "('contrast', 'max', '1')",
#  "('contrast', 'max', '2')",
#  "('contrast', 'max', '4')",
#  "('contrast', 'max', '5')",
#  "('contrast', 'max', '6')",
#  "('contrast', 'min', '1')",
#  "('contrast', 'min', '2')",
#  "('contrast', 'min', '3')",
#  "('contrast', 'min', '4')",
#  "('contrast', 'median', '1')",
#  "('contrast', 'median', '2')",
#  "('contrast', 'median', '3')",
#  "('contrast', 'median', '6')",
#  "('contrast', 'skew', '1')",
#  "('contrast', 'skew', '2')",
#  "('contrast', 'skew', '3')",
#  "('contrast', 'skew', '4')",
#  "('contrast', 'skew', '5')",
#  "('contrast', 'skew', '6')",
#  "('contrast', 'kurtosis', '1')",
#  "('contrast', 'kurtosis', '2')",
#  "('contrast', 'kurtosis', '5')"]

# %%
X_train_scaled_df = pd.DataFrame(data=X_train_scaled, columns = X.columns)
X_test_scaled_df = pd.DataFrame(data=X_test_scaled, columns = X.columns)

new_X_train_scaled = X_train_scaled_df.loc[ : , rfe_feature ]
new_X_test_scaled = X_test_scaled_df.loc[ : , rfe_feature ]
new_complete_unscaled_dataset = X.loc[ : , rfe_feature ]

# %%
ipd.display(new_X_train_scaled)
# Out:
#        ('mfcc', 'mean', '1')  ('mfcc', 'mean', '2')  ('mfcc', 'mean', '3')  \
# 0                   0.358346              -0.392125              -0.625092
# 1                  -0.649440               0.568524              -0.378565
# 2                  -0.022787              -0.450542               0.047828
# 3                   0.742223               0.005785              -1.502171
# 4                   1.071824              -2.632511               0.708163
# ...                      ...                    ...                    ...
# 18613               1.318773               0.136060              -0.104114
# 18614               1.069598              -0.542899              -0.911416
# 18615              -0.489693               0.345394              -0.126328
# 18616               0.258968              -0.400192              -0.197810
# 18617              -0.383118              -0.955129               0.584247
#
#        ('mfcc', 'mean', '4')  ('mfcc', 'mean', '5')  ('mfcc', 'mean', '6')  \
# 0                   0.097968              -1.000884              -1.285208
# 1                  -0.272611              -0.070639               0.062965
# 2                  -0.638591              -0.592490              -0.532755
# 3                   0.871068               0.571317               0.332460
# 4                  -0.094058               0.627534               0.711103
# ...                      ...                    ...                    ...
# 18613               0.332131               0.148791               1.032938
# 18614               0.930632              -0.892900              -1.586640
# 18615              -0.631792              -0.225688              -1.091359
# 18616               0.748423              -0.856889               0.243446
# 18617               0.003377              -0.653471               1.059826
#
#        ('mfcc', 'mean', '7')  ('mfcc', 'mean', '8')  ('mfcc', 'mean', '9')  \
# 0                  -0.783233              -1.681204               0.226844
# 1                  -0.837034              -0.465356              -0.522896
# 2                  -0.444316              -0.528964              -0.174233
# 3                   0.037412               0.233263               0.311890
# 4                   0.510305               0.374185               0.998855
# ...                      ...                    ...                    ...
# 18613              -1.862257              -1.693107              -1.189003
# 18614              -1.010367              -0.613027              -1.555250
# 18615              -0.992009              -1.362263              -3.261363
# 18616               0.699057              -0.279915              -0.522583
# 18617              -1.439774              -0.108345              -0.485196
#
#        ('mfcc', 'mean', '11')  ...  ('contrast', 'median', '6')  \
# 0                   -0.897728  ...                     1.144744
# 1                   -0.775177  ...                    -0.975197
# 2                    0.140008  ...                    -0.601672
# 3                   -0.779972  ...                    -0.105806
# 4                    2.217358  ...                    -0.717407
# ...                       ...  ...                          ...
# 18613               -0.999002  ...                    -0.364132
# 18614               -1.333871  ...                     0.208170
# 18615               -4.695186  ...                     0.612041
# 18616                0.815783  ...                     0.278931
# 18617                0.104913  ...                    -0.432145
#
#        ('contrast', 'skew', '1')  ('contrast', 'skew', '2')  \
# 0                       0.789560                  -0.056257
# 1                       0.139592                   0.066318
# 2                       0.057849                  -1.176290
# 3                       0.999046                   0.646324
# 4                      -0.577859                  -0.057143
# ...                          ...                        ...
# 18613                   0.969878                   0.612136
# 18614                   0.579288                   0.588202
# 18615                  -1.326116                  -0.066106
# 18616                   0.378581                  -1.014760
# 18617                  -0.523836                   0.234944
#
#        ('contrast', 'skew', '3')  ('contrast', 'skew', '4')  \
# 0                      -0.350060                  -0.812709
# 1                       0.834123                   2.526841
# 2                       0.049241                   0.861453
# 3                       1.040138                   0.923565
# 4                      -1.019878                  -0.118287
# ...                          ...                        ...
# 18613                   0.659244                   0.207210
# 18614                   1.309887                   0.946444
# 18615                  -0.670303                   0.302773
# 18616                   0.471530                   0.574422
# 18617                   0.445679                   0.909007
#
#        ('contrast', 'skew', '5')  ('contrast', 'skew', '6')  \
# 0                      -0.596442                  -0.732626
# 1                       0.817101                   0.351460
# 2                      -0.170857                   0.778765
# 3                       0.174294                  -0.625165
# 4                       0.141757                   1.012589
# ...                          ...                        ...
# 18613                  -0.044339                   0.677409
# 18614                   0.003381                  -0.703009
# 18615                   0.055312                   0.366957
# 18616                  -0.128209                  -1.083026
# 18617                   0.609820                   0.246527
#
#        ('contrast', 'kurtosis', '1')  ('contrast', 'kurtosis', '2')  \
# 0                           0.702472                      -0.224109
# 1                          -0.366489                      -0.213213
# 2                          -0.344661                      -0.592479
# 3                           0.221781                      -0.002527
# 4                          -0.505605                      -0.490076
# ...                              ...                            ...
# 18613                       0.310205                       0.547560
# 18614                       0.367974                       0.150695
# 18615                      -0.838858                      -0.032396
# 18616                       0.341894                      -0.240003
# 18617                      -0.700417                      -0.498867
#
#        ('contrast', 'kurtosis', '5')
# 0                          -0.525696
# 1                          -0.138326
# 2                          -0.359217
# 3                          -0.044573
# 4                          -0.520270
# ...                              ...
# 18613                      -0.078726
# 18614                      -0.073191
# 18615                      -0.395116
# 18616                       0.031975
# 18617                      -0.254551
#
# [18618 rows x 172 columns]

# %%
#Oversampling dei dati di training
#SMOTE resampling
from imblearn.over_sampling import SMOTE, ADASYN
X_train_resampled, y_train_resampled = SMOTE().fit_resample(new_X_train_scaled, y_train)

# %%
clf = LogisticRegression(random_state=0, max_iter = 2000).fit(X_train_resampled, y_train_resampled)

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower


# Predict the test set
predictions = clf.predict(new_X_test_scaled)
# Generate confusion matrix
matrix = plot_confusion_matrix(clf, new_X_test_scaled, y_test,
                                 cmap=plt.cm.Blues,
                                 normalize='true')
plt.title('Matrice di confusione')
plt.show(matrix)

print(classification_report(y_test, predictions))


print("Accuracy: ", accuracy_score(y_test, predictions))

(unique, counts) = np.unique(predictions, return_counts=True)
frequencies = np.asarray((unique, counts)).T

print("\nNumero di tracce assegnate ad ogni classe: \n", frequencies)
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.68      0.54      0.60      2104
#  Experimental       0.33      0.37      0.35       739
#          Folk       0.57      0.58      0.58       915
#       Hip-Hop       0.61      0.69      0.65      1136
#  Instrumental       0.38      0.46      0.42       718
# International       0.29      0.49      0.36       457
#           Pop       0.25      0.25      0.25       765
#          Rock       0.78      0.69      0.73      2337
#
#      accuracy                           0.55      9171
#     macro avg       0.49      0.51      0.49      9171
#  weighted avg       0.58      0.55      0.56      9171
#
# Accuracy:  0.5549013193762948
#
# Numero di tracce assegnate ad ogni classe:
#  [['Electronic' 1664]
#  ['Experimental' 816]
#  ['Folk' 935]
#  ['Hip-Hop' 1288]
#  ['Instrumental' 857]
#  ['International' 784]
#  ['Pop' 743]
#  ['Rock' 2084]]

# %%
new_complete_unscaled_dataset.to_csv("dataset_half_columns.csv")
